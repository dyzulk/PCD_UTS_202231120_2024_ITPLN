# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Muat Gambar (Deteksi Warna)

# %%
image = cv2.imread('PXL_20240511_181834969.NIGHT.jpg')

# %% [markdown]
# # Sesuaikan Kontras

# %% [markdown]
# # Di sini, alpha adalah kontrol kontras [1.0-3.0], dan beta adalah kontrol kecerahan [0-100]

# %%
alpha = 1.5
beta = 50
contrast_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# %% [markdown]
# # Konversi ke RGB

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Dibagi menjadi Saluran RGB

# %%
R,G,B = cv2.split(image_rgb)

# %% [markdown]
# # Tampilkan Gambar

# %%
images = [contrast_image,R,G,B]
titles = ['Citra Kontras', 'Citra Merah', 'Citra Hijau', 'Citra Biru']
for i in range(4):
    plt.subplot(2,4,i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %% [markdown]
# # Hitung dan plot histogram untuk setiap saluran

# %%
color = ('b','g','r')
for i, col in enumerate(color):
    plt.subplot(2,4, i+5)
    histr = cv2.calcHist([image],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim([0,245])
    plt.title('Histogram'+col.upper())

plt.show()

# %% [markdown]
# # Muat Gambar (Citra Threshold)

# %%
img = cv2.imread('PXL_20240511_181834969.NIGHT.jpg')

# %% [markdown]
# # Mengubah citra ke ruang warna RGB

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Membagi citra menjadi channel warna R, G, dan B

# %%
r, g, b = cv2.split(img_rgb)

# %% [markdown]
# # Membuat list untuk menyimpan citra threshold

# %%
thresh_images = []
titles = ['None', 'Biru', 'Merah-Biru', 'Merah-Hijau-Biru']

# %% [markdown]
# # Melakukan thresholding untuk setiap kondisi

# %%
for i, channel in enumerate([img, b, r-b, r-g-b]):
    # Menghitung histogram
    hist = cv2.calcHist([channel], [0], None, [256], [0,256])

    # Mencari nilai ambang batas
    thresholds = []
    for i in range(1, 255):
        if hist[i-1] < hist[i] and hist[i+1] < hist[i]:
            thresholds.append(i)

    # Mengurutkan nilai ambang batas
    thresholds.sort()

    # Melakukan thresholding dengan latar belakang hitam
    _, thresh_img = cv2.threshold(channel, thresholds[0], 255, cv2.THRESH_BINARY_INV)
    thresh_images.append(thresh_img)

# %% [markdown]
# # Menampilkan citra threshold

# %%
plt.figure(figsize=(10, 10))
for i in range(4):
    plt.subplot(1, 4, i+1), plt.imshow(thresh_images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Muat Gambar

# %%
image = cv2.imread('PXL_20240511_181834969.NIGHT.jpg')

# %% [markdown]
# # Konversi ke RGB

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Dibagi menjadi Saluran RGB

# %%
R, G, B = cv2.split(image_rgb)

# %% [markdown]
# # Hitung histogram untuk setiap saluran

# %%
hist_R = cv2.calcHist([R], [0], None, [256], [0,256])
hist_G = cv2.calcHist([G], [0], None, [256], [0,256])
hist_B = cv2.calcHist([B], [0], None, [256], [0,256])

# %% [markdown]
# # Temukan ambang batas untuk setiap saluran

# %%
threshold_R = np.argmax(hist_R)
threshold_G = np.argmax(hist_G)
threshold_B = np.argmax(hist_B)

# %% [markdown]
# # Urutkan ambang batas

# %%
thresholds = sorted([threshold_R, threshold_G, threshold_B])

# %% [markdown]
# # Cetak ambang batas

# %%
print("Thresholds (R, G, B):", thresholds)
# Out:
# Thresholds (R, G, B): [190, 193, 211]
